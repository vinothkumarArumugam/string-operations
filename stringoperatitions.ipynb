# %%
name="vinoth {} learning {} python "
name.format("is","core")
# Out:
# 'vinoth is learning core python '

# %%
name.casefold()
# Out:
# 'vinoth {} learning {} python '

# %%
name="vinoth is learning core python"
name.casefold()
# Out:
# 'vinoth is learning core python'

# %%
name="vinoth kumar 12132 @#"
name.center(50,"@")
# Out:
# '@@@@@@@@@@@@@@vinoth kumar 12132 @#@@@@@@@@@@@@@@@'

# %%
name="vinoth is learning core python"
name.count("i")
# Out:
# 3

# %%
len(name)
# Out:
# 30

# %%
name.count("i",6,30)
# Out:
# 2

# %%
name.count("i",7,30)
# Out:
# 2

# %%
name.count("vinoth")
# Out:
# 1

# %%
name.count("vin")
# Out:
# 1

# %%
name="          vinoth  kumar         "
name.count(" ")
# Out:
# 21

# %%
name.count("t")
# Out:
# 1

# %%
name.encode()
# Out:
# b'          vinoth  kumar         '

# %%
name.encode(encoding="utf-16")
# Out:
# b'\xff\xfe \x00 \x00 \x00 \x00 \x00 \x00 \x00 \x00 \x00 \x00v\x00i\x00n\x00o\x00t\x00h\x00 \x00 \x00k\x00u\x00m\x00a\x00r\x00 \x00 \x00 \x00 \x00 \x00 \x00 \x00 \x00 \x00'

# %%
tt=name.encode(encoding="utf-16")

# %%
print(tt.decode(encoding="utf-16"))
# Out:
#           vinoth  kumar
